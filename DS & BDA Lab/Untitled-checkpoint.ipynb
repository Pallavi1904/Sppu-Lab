# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("tips_DV.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.rename(columns = {'size':'people'}, inplace = True)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  people
# 0         16.99  1.01  Female     No   Sun  Dinner       2
# 1         10.34  1.66    Male     No   Sun  Dinner       3
# 2         21.01  3.50    Male     No   Sun  Dinner       3
# 3         23.68  3.31    Male     No   Sun  Dinner       2
# 4         24.59  3.61  Female     No   Sun  Dinner       4
# ..          ...   ...     ...    ...   ...     ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner       3
# 240       27.18  2.00  Female    Yes   Sat  Dinner       2
# 241       22.67  2.00    Male    Yes   Sat  Dinner       2
# 242       17.82  1.75    Male     No   Sat  Dinner       2
# 243       18.78  3.00  Female     No  Thur  Dinner       2
#
# [244 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# people        0
# dtype: int64

# %%
colvar = df[['people','sex', 'smoker', 'day', 'time']]
for i in colvar:
    print(i, df[i].unique())
# Out:
# people [2 3 4 1 6 5]
# sex ['Female' 'Male']
# smoker ['No' 'Yes']
# day ['Sun' 'Sat' 'Thur' 'Fri']
# time ['Dinner' 'Lunch']

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'people'], dtype='object')

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm',linewidths=2, square=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df, hue='sex')

# %%
sns.lineplot(df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x='total_bill', y='tip', data=df, scatter=True, line_kws={"color": "red"})
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(df,x='people',y='tip')
# Out:
# <Axes: xlabel='people', ylabel='tip'>

# %%
sns.lineplot(df,x='people',y='tip',hue='time')
# Out:
# <Axes: xlabel='people', ylabel='tip'>

# %%
sns.boxplot(df,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(df,x='people',y='total_bill',hue='day')
# Out:
# <Axes: xlabel='people', ylabel='total_bill'>

# %%
sns.boxplot(df,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(df,x='total_bill',hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(df,x='tip',hue='sex')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(df,x='tip',hue='smoker')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.scatterplot(df,x='total_bill',y='tip',hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(df,x='total_bill',y='tip',hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.violinplot(df,x ='day', y ='tip')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(df,x ='time', y ='tip',hue='day')
# Out:
# <Axes: xlabel='time', ylabel='tip'>

# %%
sns.violinplot(df,x ='people', y ='total_bill')
# Out:
# <Axes: xlabel='people', ylabel='total_bill'>
